# %% [markdown]
# <a href="https://colab.research.google.com/github/Jesusleg95/AnalisisDatosPython/blob/main/VisualizacionesUnivariales/GraficoBarras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Objetivo actual:** Visualizar cuantos pasajeros hombres y cuantas pasajeras mujeres habia en el Titanic.

# %%
pasajeros = df.groupby('Sex').agg({
    'PassengerId':'count'
})
pasajeros
# Out:
#         PassengerId
# Sex
# female          314
# male            577

# %% [markdown]
# **Grafico con Pandas**

# %%
pasajeros.plot.bar(
    y='PassengerId'
)
# Out:
# <Axes: xlabel='Sex'>

# %%
pasajeros.plot.bar(
    y='PassengerId',
    width=0.3
)
# Out:
# <Axes: xlabel='Sex'>

# %%
pasajeros.plot.bar(
    y='PassengerId',
    title = 'Numero de Pasajeros por Sexo'
)
# Out:
# <Axes: title={'center': 'Numero de Pasajeros por Sexo'}, xlabel='Sex'>

# %% [markdown]
# **Grafico con seaborn**

# %%
import seaborn as sns

# %%
pasajeros2 = pasajeros.reset_index()
pasajeros2
# Out:
#       Sex  PassengerId
# 0  female          314
# 1    male          577

# %%
sns.barplot(
    pasajeros2,
    x='Sex',
    y='PassengerId'
)
# Out:
# <Axes: xlabel='Sex', ylabel='PassengerId'>

# %% [markdown]
# **Grafico con matplotlib**

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(
    pasajeros2['Sex'],
    pasajeros2['PassengerId']
)
# Out:
# <BarContainer object of 2 artists>
